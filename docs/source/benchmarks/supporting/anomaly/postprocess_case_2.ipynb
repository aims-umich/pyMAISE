# %%
"""
postprocess_case_2.py

Postprocessing script which you can adopt in your benchmark.
I recommend increasing the number of epochs you train the final
models to.
"""

import pickle

import pyMAISE as mai
import settings
from preprocessing import load_anomaly_data, split_sequences

# Initialize pyMAISE
mai.init(
    problem_type=settings.problem_type,
    verbosity=settings.verbosity,
    random_state=settings.random_state,
    cuda_visible_devices="1",  # Use GPU 1
)

# Load training/testing data
data = load_anomaly_data(
    stack_series=True,
    multiclass=False,
    test_size=0.3,
    non_faulty_frac=settings.non_faulty_frac,
    timestep_step=10,
)

# Combine data and create rolling windows using SplitSequence
xtrain, xtest, ytrain, ytest = split_sequences(
    data=data[:-1],
    input_steps=10,
    output_steps=1,
    output_position=0,
)

# Read pickled configs
with open("./configs/binary_case_2.pkl", "rb") as f:
    configs = pickle.load(f)
# Out:
# 2024-05-25 14:47:56.984722: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-25 14:47:56.984769: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-25 14:47:56.986029: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-25 14:47:56.993287: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-25 14:47:57.754469: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-25 14:47:59.414694: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.456957: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.457268: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.647035: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.647354: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.647594: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.769316: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.769594: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.769871: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-25 14:47:59.770083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20023 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# Num GPUs Available:  1
# xtrain shape: (220, 450, 14)
# xtest shape: (95, 450, 14)
# ytrain shape: (220, 450, 2)
# ytest shape: (95, 450, 2)

# %%
# Model postprocessing
postprocessor = mai.PostProcessor(
    data=(xtrain, xtest, ytrain, ytest),
    model_configs=[configs],
    new_model_settings={
        "LSTM": {"fitting_params": {"epochs": 50}},
    },
)

print(postprocessor.metrics())

for model in ["LSTM"]:
    for key, value in postprocessor.get_params(model_type=model).to_dict().items():
        print(f"{key}: {value[0]}")
    print()
# Out:
# 2024-05-24 20:39:43.325096: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-24 20:39:43.325156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-24 20:39:43.326426: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-24 20:39:43.333181: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-24 20:39:44.091707: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-24 20:39:45.774267: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.809869: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.810181: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.992524: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Num GPUs Available:  1
# xtrain shape: (220, 450, 14)
# xtest shape: (95, 450, 14)
# ytrain shape: (220, 450, 2)
# ytest shape: (95, 450, 2)
# 2024-05-24 20:39:45.992817: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.993036: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.123755: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124184: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124439: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 857 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# Epoch 1/50
# 2024-05-24 20:39:51.568245: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-05-24 20:39:52.129250: I external/local_xla/xla/service/service.cc:168] XLA service 0x7c62344cec90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-24 20:39:52.129280: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-05-24 20:39:52.134738: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716597592.250362 4061313 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 12s 4ms/step
# 1336/1336 [==============================] - 5s 3ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 11s 3ms/step
# 1336/1336 [==============================] - 4s 3ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
#    Model Types                           Parameter Configurations  \
# 0         LSTM  {'LSTM_input_0_units': 30, 'LSTM_num_layers': ...
# 1         LSTM  {'LSTM_input_0_units': 43, 'LSTM_num_layers': ...
# 3         LSTM  {'LSTM_input_0_units': 26, 'LSTM_num_layers': ...
# 10    CNN_LSTM  {'Conv1D_0_filters': 150, 'LSTM_num_layers': 2...
# 2         LSTM  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
# 4         LSTM  {'LSTM_input_0_units': 27, 'LSTM_num_layers': ...
# 6          GRU  {'LSTM_input_0_units': 61, 'LSTM_num_layers': ...
# 5          GRU  {'LSTM_input_0_units': 55, 'LSTM_num_layers': ...
# 11    CNN_LSTM  {'Conv1D_0_filters': 115, 'LSTM_num_layers': 2...
# 13    CNN_LSTM  {'Conv1D_0_filters': 125, 'LSTM_num_layers': 2...
# 9          GRU  {'LSTM_input_0_units': 69, 'LSTM_num_layers': ...
# 8          GRU  {'LSTM_input_0_units': 46, 'LSTM_num_layers': ...
# 14    CNN_LSTM  {'Conv1D_0_filters': 108, 'LSTM_num_layers': 2...
# 12    CNN_LSTM  {'Conv1D_0_filters': 123, 'LSTM_num_layers': 1...
# 7          GRU  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
#
#     Train Accuracy  Train Recall  Train Precision  Train F1  Test Accuracy  \
# 0         0.812872      0.812872         0.812872  0.812872       0.694883
# 1         0.809134      0.809134         0.809134  0.809134       0.690952
# 3         0.823721      0.823721         0.823721  0.823721       0.688028
# 10        0.791425      0.791425         0.791425  0.791425       0.683816
# 2         0.817529      0.817529         0.817529  0.817529       0.682272
# 4         0.820701      0.820701         0.820701  0.820701       0.677827
# 6         0.802730      0.802730         0.802730  0.802730       0.676821
# 5         0.780556      0.780556         0.780556  0.780556       0.676353
# 11        0.794082      0.794082         0.794082  0.794082       0.672492
# 13        0.802588      0.802588         0.802588  0.802588       0.672399
# 9         0.790072      0.790072         0.790072  0.790072       0.669778
# 8         0.772565      0.772565         0.772565  0.772565       0.666035
# 14        0.772010      0.772010         0.772010  0.772010       0.660162
# 12        0.770848      0.770848         0.770848  0.770848       0.657986
# 7         0.739825      0.739825         0.739825  0.739825       0.649306
#
#     Test Recall  Test Precision   Test F1
# 0      0.694883        0.694883  0.694883
# 1      0.690952        0.690952  0.690952
# 3      0.688028        0.688028  0.688028
# 10     0.683816        0.683816  0.683816
# 2      0.682272        0.682272  0.682272
# 4      0.677827        0.677827  0.677827
# 6      0.676821        0.676821  0.676821
# 5      0.676353        0.676353  0.676353
# 11     0.672492        0.672492  0.672492
# 13     0.672399        0.672399  0.672399
# 9      0.669778        0.669778  0.669778
# 8      0.666035        0.666035  0.666035
# 14     0.660162        0.660162  0.660162
# 12     0.657986        0.657986  0.657986
# 7      0.649306        0.649306  0.649306
# Model Types: LSTM
# LSTM_input_0_units: 30
# LSTM_num_layers: 2
# LSTM_output_0_units: 69
# LSTM_output_0_activation: tanh
# Dense_num_layers: 0
# Adam_learning_rate: 0.0007029329662303363
# LSTM_0_units: 25
# LSTM_0_activation: tanh
# LSTM_1_units: 29
# LSTM_1_activation: tanh
# LSTM_2_units: 25
# LSTM_2_activation: tanh
# batch_size: 32
# Dense_0_units: 48
# Dense_1_units: 36
# Dense_2_units: 25

# %%
# Model postprocessing
postprocessor = mai.PostProcessor(
    data=(xtrain, xtest, ytrain, ytest),
    model_configs=[configs],
    new_model_settings={
        "LSTM": {"fitting_params": {"epochs": 50}},
    },
)

print(postprocessor.metrics())

for model in ["LSTM"]:
    for key, value in postprocessor.get_params(model_type=model).to_dict().items():
        print(f"{key}: {value[0]}")
    print()
# Out:
# 2024-05-24 20:39:43.325096: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-24 20:39:43.325156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-24 20:39:43.326426: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-24 20:39:43.333181: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-24 20:39:44.091707: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-24 20:39:45.774267: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.809869: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.810181: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.992524: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Num GPUs Available:  1
# xtrain shape: (220, 450, 14)
# xtest shape: (95, 450, 14)
# ytrain shape: (220, 450, 2)
# ytest shape: (95, 450, 2)
# 2024-05-24 20:39:45.992817: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.993036: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.123755: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124184: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124439: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 857 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# Epoch 1/50
# 2024-05-24 20:39:51.568245: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-05-24 20:39:52.129250: I external/local_xla/xla/service/service.cc:168] XLA service 0x7c62344cec90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-24 20:39:52.129280: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-05-24 20:39:52.134738: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716597592.250362 4061313 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 12s 4ms/step
# 1336/1336 [==============================] - 5s 3ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 11s 3ms/step
# 1336/1336 [==============================] - 4s 3ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
#    Model Types                           Parameter Configurations  \
# 0         LSTM  {'LSTM_input_0_units': 30, 'LSTM_num_layers': ...
# 1         LSTM  {'LSTM_input_0_units': 43, 'LSTM_num_layers': ...
# 3         LSTM  {'LSTM_input_0_units': 26, 'LSTM_num_layers': ...
# 10    CNN_LSTM  {'Conv1D_0_filters': 150, 'LSTM_num_layers': 2...
# 2         LSTM  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
# 4         LSTM  {'LSTM_input_0_units': 27, 'LSTM_num_layers': ...
# 6          GRU  {'LSTM_input_0_units': 61, 'LSTM_num_layers': ...
# 5          GRU  {'LSTM_input_0_units': 55, 'LSTM_num_layers': ...
# 11    CNN_LSTM  {'Conv1D_0_filters': 115, 'LSTM_num_layers': 2...
# 13    CNN_LSTM  {'Conv1D_0_filters': 125, 'LSTM_num_layers': 2...
# 9          GRU  {'LSTM_input_0_units': 69, 'LSTM_num_layers': ...
# 8          GRU  {'LSTM_input_0_units': 46, 'LSTM_num_layers': ...
# 14    CNN_LSTM  {'Conv1D_0_filters': 108, 'LSTM_num_layers': 2...
# 12    CNN_LSTM  {'Conv1D_0_filters': 123, 'LSTM_num_layers': 1...
# 7          GRU  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
#
#     Train Accuracy  Train Recall  Train Precision  Train F1  Test Accuracy  \
# 0         0.812872      0.812872         0.812872  0.812872       0.694883
# 1         0.809134      0.809134         0.809134  0.809134       0.690952
# 3         0.823721      0.823721         0.823721  0.823721       0.688028
# 10        0.791425      0.791425         0.791425  0.791425       0.683816
# 2         0.817529      0.817529         0.817529  0.817529       0.682272
# 4         0.820701      0.820701         0.820701  0.820701       0.677827
# 6         0.802730      0.802730         0.802730  0.802730       0.676821
# 5         0.780556      0.780556         0.780556  0.780556       0.676353
# 11        0.794082      0.794082         0.794082  0.794082       0.672492
# 13        0.802588      0.802588         0.802588  0.802588       0.672399
# 9         0.790072      0.790072         0.790072  0.790072       0.669778
# 8         0.772565      0.772565         0.772565  0.772565       0.666035
# 14        0.772010      0.772010         0.772010  0.772010       0.660162
# 12        0.770848      0.770848         0.770848  0.770848       0.657986
# 7         0.739825      0.739825         0.739825  0.739825       0.649306
#
#     Test Recall  Test Precision   Test F1
# 0      0.694883        0.694883  0.694883
# 1      0.690952        0.690952  0.690952
# 3      0.688028        0.688028  0.688028
# 10     0.683816        0.683816  0.683816
# 2      0.682272        0.682272  0.682272
# 4      0.677827        0.677827  0.677827
# 6      0.676821        0.676821  0.676821
# 5      0.676353        0.676353  0.676353
# 11     0.672492        0.672492  0.672492
# 13     0.672399        0.672399  0.672399
# 9      0.669778        0.669778  0.669778
# 8      0.666035        0.666035  0.666035
# 14     0.660162        0.660162  0.660162
# 12     0.657986        0.657986  0.657986
# 7      0.649306        0.649306  0.649306
# Model Types: LSTM
# LSTM_input_0_units: 30
# LSTM_num_layers: 2
# LSTM_output_0_units: 69
# LSTM_output_0_activation: tanh
# Dense_num_layers: 0
# Adam_learning_rate: 0.0007029329662303363
# LSTM_0_units: 25
# LSTM_0_activation: tanh
# LSTM_1_units: 29
# LSTM_1_activation: tanh
# LSTM_2_units: 25
# LSTM_2_activation: tanh
# batch_size: 32
# Dense_0_units: 48
# Dense_1_units: 36
# Dense_2_units: 25

# %%
# Model postprocessing
postprocessor = mai.PostProcessor(
    data=(xtrain, xtest, ytrain, ytest),
    model_configs=[configs],
    new_model_settings={
        "LSTM": {"fitting_params": {"epochs": 50}},
    },
)

print(postprocessor.metrics())

for model in ["LSTM"]:
    for key, value in postprocessor.get_params(model_type=model).to_dict().items():
        print(f"{key}: {value[0]}")
    print()
# Out:
# 2024-05-24 20:39:43.325096: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-24 20:39:43.325156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-24 20:39:43.326426: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-24 20:39:43.333181: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-24 20:39:44.091707: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-24 20:39:45.774267: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.809869: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.810181: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.992524: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Num GPUs Available:  1
# xtrain shape: (220, 450, 14)
# xtest shape: (95, 450, 14)
# ytrain shape: (220, 450, 2)
# ytest shape: (95, 450, 2)
# 2024-05-24 20:39:45.992817: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:45.993036: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.123755: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124184: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124439: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-24 20:39:46.124632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 857 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# Epoch 1/50
# 2024-05-24 20:39:51.568245: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-05-24 20:39:52.129250: I external/local_xla/xla/service/service.cc:168] XLA service 0x7c62344cec90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-24 20:39:52.129280: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-05-24 20:39:52.134738: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716597592.250362 4061313 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 12s 4ms/step
# 1336/1336 [==============================] - 5s 3ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 11s 3ms/step
# 1336/1336 [==============================] - 4s 3ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
#    Model Types                           Parameter Configurations  \
# 0         LSTM  {'LSTM_input_0_units': 30, 'LSTM_num_layers': ...
# 1         LSTM  {'LSTM_input_0_units': 43, 'LSTM_num_layers': ...
# 3         LSTM  {'LSTM_input_0_units': 26, 'LSTM_num_layers': ...
# 10    CNN_LSTM  {'Conv1D_0_filters': 150, 'LSTM_num_layers': 2...
# 2         LSTM  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
# 4         LSTM  {'LSTM_input_0_units': 27, 'LSTM_num_layers': ...
# 6          GRU  {'LSTM_input_0_units': 61, 'LSTM_num_layers': ...
# 5          GRU  {'LSTM_input_0_units': 55, 'LSTM_num_layers': ...
# 11    CNN_LSTM  {'Conv1D_0_filters': 115, 'LSTM_num_layers': 2...
# 13    CNN_LSTM  {'Conv1D_0_filters': 125, 'LSTM_num_layers': 2...
# 9          GRU  {'LSTM_input_0_units': 69, 'LSTM_num_layers': ...
# 8          GRU  {'LSTM_input_0_units': 46, 'LSTM_num_layers': ...
# 14    CNN_LSTM  {'Conv1D_0_filters': 108, 'LSTM_num_layers': 2...
# 12    CNN_LSTM  {'Conv1D_0_filters': 123, 'LSTM_num_layers': 1...
# 7          GRU  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
#
#     Train Accuracy  Train Recall  Train Precision  Train F1  Test Accuracy  \
# 0         0.812872      0.812872         0.812872  0.812872       0.694883
# 1         0.809134      0.809134         0.809134  0.809134       0.690952
# 3         0.823721      0.823721         0.823721  0.823721       0.688028
# 10        0.791425      0.791425         0.791425  0.791425       0.683816
# 2         0.817529      0.817529         0.817529  0.817529       0.682272
# 4         0.820701      0.820701         0.820701  0.820701       0.677827
# 6         0.802730      0.802730         0.802730  0.802730       0.676821
# 5         0.780556      0.780556         0.780556  0.780556       0.676353
# 11        0.794082      0.794082         0.794082  0.794082       0.672492
# 13        0.802588      0.802588         0.802588  0.802588       0.672399
# 9         0.790072      0.790072         0.790072  0.790072       0.669778
# 8         0.772565      0.772565         0.772565  0.772565       0.666035
# 14        0.772010      0.772010         0.772010  0.772010       0.660162
# 12        0.770848      0.770848         0.770848  0.770848       0.657986
# 7         0.739825      0.739825         0.739825  0.739825       0.649306
#
#     Test Recall  Test Precision   Test F1
# 0      0.694883        0.694883  0.694883
# 1      0.690952        0.690952  0.690952
# 3      0.688028        0.688028  0.688028
# 10     0.683816        0.683816  0.683816
# 2      0.682272        0.682272  0.682272
# 4      0.677827        0.677827  0.677827
# 6      0.676821        0.676821  0.676821
# 5      0.676353        0.676353  0.676353
# 11     0.672492        0.672492  0.672492
# 13     0.672399        0.672399  0.672399
# 9      0.669778        0.669778  0.669778
# 8      0.666035        0.666035  0.666035
# 14     0.660162        0.660162  0.660162
# 12     0.657986        0.657986  0.657986
# 7      0.649306        0.649306  0.649306
# Model Types: LSTM
# LSTM_input_0_units: 30
# LSTM_num_layers: 2
# LSTM_output_0_units: 69
# LSTM_output_0_activation: tanh
# Dense_num_layers: 0
# Adam_learning_rate: 0.0007029329662303363
# LSTM_0_units: 25
# LSTM_0_activation: tanh
# LSTM_1_units: 29
# LSTM_1_activation: tanh
# LSTM_2_units: 25
# LSTM_2_activation: tanh
# batch_size: 32
# Dense_0_units: 48
# Dense_1_units: 36
# Dense_2_units: 25

# %%
postprocessor = mai.PostProcessor(
    data=(xtrain, xtest, ytrain, ytest),
    model_configs=[configs],
    new_model_settings={
        "GRU": {"fitting_params": {"epochs": 50}},
    },
)

print(postprocessor.metrics())

for model in ["GRU"]:
    for key, value in postprocessor.get_params(model_type=model).to_dict().items():
        print(f"{key}: {value[0]}")
    print()
# Out:
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 12s 4ms/step
# 1336/1336 [==============================] - 5s 4ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 9s 3ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 11s 3ms/step
# 1336/1336 [==============================] - 4s 3ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
#    Model Types                           Parameter Configurations  \
# 6          GRU  {'LSTM_input_0_units': 61, 'LSTM_num_layers': ...
# 7          GRU  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
# 4         LSTM  {'LSTM_input_0_units': 27, 'LSTM_num_layers': ...
# 0         LSTM  {'LSTM_input_0_units': 30, 'LSTM_num_layers': ...
# 13    CNN_LSTM  {'Conv1D_0_filters': 125, 'LSTM_num_layers': 2...
# 9          GRU  {'LSTM_input_0_units': 69, 'LSTM_num_layers': ...
# 1         LSTM  {'LSTM_input_0_units': 43, 'LSTM_num_layers': ...
# 8          GRU  {'LSTM_input_0_units': 46, 'LSTM_num_layers': ...
# 2         LSTM  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
# 11    CNN_LSTM  {'Conv1D_0_filters': 115, 'LSTM_num_layers': 2...
# 3         LSTM  {'LSTM_input_0_units': 26, 'LSTM_num_layers': ...
# 5          GRU  {'LSTM_input_0_units': 55, 'LSTM_num_layers': ...
# 14    CNN_LSTM  {'Conv1D_0_filters': 108, 'LSTM_num_layers': 2...
# 10    CNN_LSTM  {'Conv1D_0_filters': 150, 'LSTM_num_layers': 2...
# 12    CNN_LSTM  {'Conv1D_0_filters': 123, 'LSTM_num_layers': 1...
#
#     Train Accuracy  Train Recall  Train Precision  Train F1  Test Accuracy  \
# 6         0.803144      0.803144         0.803144  0.803144       0.695819
# 7         0.824277      0.824277         0.824277  0.824277       0.693667
# 4         0.822327      0.822327         0.822327  0.822327       0.686952
# 0         0.820256      0.820256         0.820256  0.820256       0.684893
# 13        0.788193      0.788193         0.788193  0.788193       0.681711
# 9         0.815680      0.815680         0.815680  0.815680       0.681219
# 1         0.823075      0.823075         0.823075  0.823075       0.679207
# 8         0.812761      0.812761         0.812761  0.812761       0.679207
# 2         0.817034      0.817034         0.817034  0.817034       0.677663
# 11        0.794335      0.794335         0.794335  0.794335       0.675253
# 3         0.820357      0.820357         0.820357  0.820357       0.674879
# 5         0.816155      0.816155         0.816155  0.816155       0.669755
# 14        0.797780      0.797780         0.797780  0.797780       0.660490
# 10        0.779859      0.779859         0.779859  0.779859       0.647715
# 12        0.700761      0.700761         0.700761  0.700761       0.628507
#
#     Test Recall  Test Precision   Test F1
# 6      0.695842        0.695826  0.695834
# 7      0.693667        0.693667  0.693667
# 4      0.686952        0.686952  0.686952
# 0      0.684893        0.684893  0.684893
# 13     0.681711        0.681711  0.681711
# 9      0.681219        0.681219  0.681219
# 1      0.679207        0.679207  0.679207
# 8      0.679207        0.679207  0.679207
# 2      0.677663        0.677663  0.677663
# 11     0.675253        0.675253  0.675253
# 3      0.674879        0.674879  0.674879
# 5      0.669755        0.669755  0.669755
# 14     0.660490        0.660490  0.660490
# 10     0.647715        0.647715  0.647715
# 12     0.628507        0.628507  0.628507
# Model Types: GRU
# LSTM_input_0_units: 61
# LSTM_num_layers: 1
# LSTM_output_0_units: 40
# LSTM_output_0_activation: tanh
# Dense_num_layers: 1
# Adam_learning_rate: 0.0006560462637812724
# LSTM_0_units: 44
# LSTM_0_activation: tanh
# LSTM_1_units: 56
# LSTM_1_activation: tanh
# LSTM_2_units: 53
# LSTM_2_activation: tanh
# batch_size: 64
# Dense_0_units: 28
# Dense_1_units: 30
# Dense_2_units: 39

# %%
postprocessor = mai.PostProcessor(
    data=(xtrain, xtest, ytrain, ytest),
    model_configs=[configs],
    new_model_settings={
        "CNN_LSTM": {"fitting_params": {"epochs": 50}},
    },
)

print(postprocessor.metrics())

for model in ["CNN_LSTM"]:
    for key, value in postprocessor.get_params(model_type=model).to_dict().items():
        print(f"{key}: {value[0]}")
    print()
# Out:
# Epoch 1/10
# 2024-05-25 14:48:06.143181: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-05-25 14:48:06.651953: I external/local_xla/xla/service/service.cc:168] XLA service 0x7b3008479da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-25 14:48:06.651987: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-05-25 14:48:06.657144: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716662886.757276  155501 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 13s 4ms/step
# 1336/1336 [==============================] - 5s 4ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 1ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 11s 3ms/step
# 1336/1336 [==============================] - 4s 3ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 3094/3094 [==============================] - 5s 1ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer LSTM_output_0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 5s 2ms/step
# 1336/1336 [==============================] - 2s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 8s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
# WARNING:tensorflow:Layer LSTM_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 3094/3094 [==============================] - 7s 2ms/step
# 1336/1336 [==============================] - 3s 2ms/step
#    Model Types                           Parameter Configurations  \
# 11    CNN_LSTM  {'Conv1D_0_filters': 115, 'LSTM_num_layers': 2...
# 10    CNN_LSTM  {'Conv1D_0_filters': 150, 'LSTM_num_layers': 2...
# 14    CNN_LSTM  {'Conv1D_0_filters': 108, 'LSTM_num_layers': 2...
# 13    CNN_LSTM  {'Conv1D_0_filters': 125, 'LSTM_num_layers': 2...
# 12    CNN_LSTM  {'Conv1D_0_filters': 123, 'LSTM_num_layers': 1...
# 5          GRU  {'LSTM_input_0_units': 55, 'LSTM_num_layers': ...
# 6          GRU  {'LSTM_input_0_units': 61, 'LSTM_num_layers': ...
# 4         LSTM  {'LSTM_input_0_units': 27, 'LSTM_num_layers': ...
# 8          GRU  {'LSTM_input_0_units': 46, 'LSTM_num_layers': ...
# 7          GRU  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
# 9          GRU  {'LSTM_input_0_units': 69, 'LSTM_num_layers': ...
# 1         LSTM  {'LSTM_input_0_units': 43, 'LSTM_num_layers': ...
# 3         LSTM  {'LSTM_input_0_units': 26, 'LSTM_num_layers': ...
# 2         LSTM  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
# 0         LSTM  {'LSTM_input_0_units': 30, 'LSTM_num_layers': ...
#
#     Train Accuracy  Train Recall  Train Precision  Train F1  Test Accuracy  \
# 11        0.791910      0.791910         0.791910  0.791910       0.751690
# 10        0.792678      0.792678         0.792678  0.792678       0.745069
# 14        0.788567      0.788567         0.788567  0.788567       0.742963
# 13        0.792466      0.792466         0.792466  0.792466       0.739454
# 12        0.784334      0.784334         0.784334  0.784334       0.734564
# 5         0.781293      0.781293         0.781293  0.781293       0.733160
# 6         0.782000      0.782000         0.782000  0.782000       0.732107
# 4         0.783485      0.783485         0.783485  0.783485       0.731569
# 8         0.777616      0.777616         0.777616  0.777616       0.726796
# 7         0.779566      0.779566         0.779566  0.779566       0.724784
# 9         0.779536      0.779536         0.779536  0.779536       0.723357
# 1         0.774545      0.774545         0.774545  0.774545       0.722655
# 3         0.771494      0.771494         0.771494  0.771494       0.714513
# 2         0.770373      0.770373         0.770373  0.770373       0.713320
# 0         0.739300      0.739300         0.739300  0.739300       0.677219
#
#     Test Recall  Test Precision   Test F1
# 11     0.751690        0.751690  0.751690
# 10     0.745069        0.745069  0.745069
# 14     0.742963        0.742963  0.742963
# 13     0.739454        0.739454  0.739454
# 12     0.734564        0.734564  0.734564
# 5      0.733160        0.733160  0.733160
# 6      0.732107        0.732107  0.732107
# 4      0.731569        0.731569  0.731569
# 8      0.726796        0.726796  0.726796
# 7      0.724784        0.724784  0.724784
# 9      0.723357        0.723357  0.723357
# 1      0.722655        0.722655  0.722655
# 3      0.714513        0.714513  0.714513
# 2      0.713320        0.713320  0.713320
# 0      0.677219        0.677219  0.677219
# Model Types: CNN_LSTM
# Conv1D_0_filters: 115
# LSTM_num_layers: 2
# LSTM_output_0_units: 93
# LSTM_output_0_activation: tanh
# Adam_learning_rate: 0.0005130792788123218
# LSTM_0_units: 62
# LSTM_0_activation: tanh
# LSTM_0_recurrent_dropout: 0.0
# LSTM_1_units: 54
# LSTM_1_activation: sigmoid
# LSTM_1_recurrent_dropout: 0.6
# LSTM_2_units: 46
# LSTM_2_activation: tanh
# LSTM_2_recurrent_dropout: 0.2
# batch_size: 32
