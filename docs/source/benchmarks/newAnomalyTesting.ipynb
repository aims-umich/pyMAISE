# %%
# %load_ext autoreload
# %autoreload 2

import pickle
import matplotlib.pyplot as plt
import numpy as np
import pickle
import pyMAISE as mai



pickle_file_path = "/home/jacc/pyMAISE/docs/source/benchmarks/supporting/anomaly/configs/binary_case_1.pkl"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run /home/jacc/pyMAISE/docs/source/benchmarks/supporting/anomaly/binary_case_1.py
# Out:
# Trial 50 Complete [00h 01m 27s]
# accuracy_score: 0.6232876712328768
#
# Best accuracy_score So Far: 0.6643835616438356
# Total elapsed time: 01h 00m 04s
#
# Top Configurations
#
# -- LSTM | Training Time: 00:58:29
# LSTM_input_0_units: 50
# LSTM_num_layers: 0
# LSTM_output_0_units: 75
# Dense_num_layers: 2
# Adam_learning_rate: 0.00019944696916616427
# LSTM_0_units: 25
# LSTM_1_units: 50
# LSTM_2_units: 75
# Dense_0_units: 75
# batch_size: 128
# Dense_1_units: 50
# Dense_2_units: 50
#
# -- GRU | Training Time: 01:00:04
# LSTM_input_0_units: 75
# LSTM_num_layers: 1
# LSTM_output_0_units: 25
# Dense_num_layers: 2
# Adam_learning_rate: 0.000401888898047047
# LSTM_0_units: 75
# LSTM_1_units: 50
# LSTM_2_units: 25
# Dense_0_units: 50
# batch_size: 32
# Dense_1_units: 25
# Dense_2_units: 25

# %%
with open(pickle_file_path, 'rb') as file:
    data = pickle.load(file)

# %%
ax = tuner.convergence_plot(model_types="LSTM")
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
file_path = "/home/jacc/pyMAISE/docs/source/benchmarks/supporting/anomaly/configs/convergence_plot_lstm.png"


ax.figure.savefig(file_path)


plt.close(ax.figure)

# %%
ax = tuner.convergence_plot(model_types="GRU")
ax.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
file_path = "/home/jacc/pyMAISE/docs/source/benchmarks/supporting/anomaly/configs/convergence_plot_gru.png"

ax.figure.savefig(file_path)

plt.close(ax.figure)

# %%
postprocessor = mai.PostProcessor(
    data=(xtrain, xtest, ytrain, ytest), 
    model_configs=[configs], 
    new_model_settings={
        "LSTM": {"fitting_params": {"epochs": 10}},
    },
  #  y_scaler=y_scaler,
)
# Out:
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 7/7 [==============================] - 1s 60ms/step
# 3/3 [==============================] - 0s 72ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 7/7 [==============================] - 1s 69ms/step
# 3/3 [==============================] - 0s 68ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 7/7 [==============================] - 2s 118ms/step
# 3/3 [==============================] - 0s 119ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 7/7 [==============================] - 1s 102ms/step
# 3/3 [==============================] - 0s 102ms/step
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10
# 7/7 [==============================] - 1s 64ms/step
# 3/3 [==============================] - 0s 78ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 7/7 [==============================] - 1s 85ms/step
# 3/3 [==============================] - 0s 96ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 7/7 [==============================] - 1s 75ms/step
# 3/3 [==============================] - 0s 67ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 7/7 [==============================] - 2s 152ms/step
# 3/3 [==============================] - 1s 161ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 7/7 [==============================] - 2s 105ms/step
# 3/3 [==============================] - 0s 106ms/step
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 7/7 [==============================] - 1s 95ms/step
# 3/3 [==============================] - 0s 87ms/step

# %%
postprocessor.metrics()
# Out:
#   Model Types                           Parameter Configurations  \
# 5         GRU  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
# 7         GRU  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
# 3        LSTM  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
# 6         GRU  {'LSTM_input_0_units': 50, 'LSTM_num_layers': ...
# 0        LSTM  {'LSTM_input_0_units': 50, 'LSTM_num_layers': ...
# 4        LSTM  {'LSTM_input_0_units': 75, 'LSTM_num_layers': ...
# 8         GRU  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
# 1        LSTM  {'LSTM_input_0_units': 50, 'LSTM_num_layers': ...
# 9         GRU  {'LSTM_input_0_units': 50, 'LSTM_num_layers': ...
# 2        LSTM  {'LSTM_input_0_units': 25, 'LSTM_num_layers': ...
#
#    Train Accuracy  Train Recall  Train Precision  Train F1  Test Accuracy  \
# 5        0.663636      0.663636         0.663636  0.663636       0.578947
# 7        0.654545      0.654545         0.654545  0.654545       0.557895
# 3        0.654545      0.654545         0.654545  0.654545       0.547368
# 6        0.654545      0.654545         0.654545  0.654545       0.547368
# 0        0.622727      0.622727         0.622727  0.622727       0.536842
# 4        0.613636      0.613636         0.613636  0.613636       0.536842
# 8        0.640909      0.640909         0.640909  0.640909       0.536842
# 1        0.631818      0.631818         0.631818  0.631818       0.515789
# 9        0.631818      0.631818         0.631818  0.631818       0.515789
# 2        0.509091      0.509091         0.509091  0.509091       0.463158
#
#    Test Recall  Test Precision   Test F1
# 5     0.578947        0.578947  0.578947
# 7     0.557895        0.557895  0.557895
# 3     0.547368        0.547368  0.547368
# 6     0.547368        0.547368  0.547368
# 0     0.536842        0.536842  0.536842
# 4     0.536842        0.536842  0.536842
# 8     0.536842        0.536842  0.536842
# 1     0.515789        0.515789  0.515789
# 9     0.515789        0.515789  0.515789
# 2     0.463158        0.463158  0.463158
